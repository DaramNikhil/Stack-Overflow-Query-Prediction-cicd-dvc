# %%
import pandas as pd
import xml.etree.ElementTree as ET
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import xml.etree.ElementTree as ET

# Read the XML file into a string
data_path = "../data.xml"
with open(data_path, 'r') as file:
    tree = ET.fromstring(file.read())


# Iterate through the children of the root element
for child in tree:
    print(child)
# Out:
# <Element 'row' at 0x000001E886909D10>
# <Element 'row' at 0x000001E886909E50>
# <Element 'row' at 0x000001E886909F40>
# <Element 'row' at 0x000001E88690D0E0>
# <Element 'row' at 0x000001E88690D220>
# <Element 'row' at 0x000001E88690D310>
# <Element 'row' at 0x000001E88690D450>
# <Element 'row' at 0x000001E88690D540>
# <Element 'row' at 0x000001E88690D680>
# <Element 'row' at 0x000001E88690D7C0>
# <Element 'row' at 0x000001E88690D900>
# <Element 'row' at 0x000001E88690D9F0>
# <Element 'row' at 0x000001E88690DAE0>
# <Element 'row' at 0x000001E88690DBD0>
# <Element 'row' at 0x000001E88690DCC0>
# <Element 'row' at 0x000001E88690DDB0>
# <Element 'row' at 0x000001E88690DF40>
# <Element 'row' at 0x000001E8869150E0>
# <Element 'row' at 0x000001E886915270>
# <Element 'row' at 0x000001E886915360>
# <Element 'row' at 0x000001E8869154A0>
# <Element 'row' at 0x000001E886915590>
# <Element 'row' at 0x000001E8869156D0>
# <Element 'row' at 0x000001E886915810>
# <Element 'row' at 0x000001E886915950>
# ...

# %%
import yaml

# %%
import pandas as pd
import xml.etree.ElementTree as ET
import matplotlib.pyplot as plt
import seaborn as sns
import yaml

with open("D:\my_projects\stack_overflow_qwery_prediction_dvc_cicd\data.xml", "r") as f:
    tree = ET.fromstring(f.read())
    for ts in tree:
        print(ts)
# Out:
# <Element 'row' at 0x000001E8869715E0>
# <Element 'row' at 0x000001E886971720>
# <Element 'row' at 0x000001E886971810>
# <Element 'row' at 0x000001E886971950>
# <Element 'row' at 0x000001E886971A90>
# <Element 'row' at 0x000001E886971B80>
# <Element 'row' at 0x000001E886971CC0>
# <Element 'row' at 0x000001E886971DB0>
# <Element 'row' at 0x000001E886971EF0>
# <Element 'row' at 0x000001E886973090>
# <Element 'row' at 0x000001E8869731D0>
# <Element 'row' at 0x000001E8869732C0>
# <Element 'row' at 0x000001E8869733B0>
# <Element 'row' at 0x000001E8869734A0>
# <Element 'row' at 0x000001E886973590>
# <Element 'row' at 0x000001E886973680>
# <Element 'row' at 0x000001E886973810>
# <Element 'row' at 0x000001E886973950>
# <Element 'row' at 0x000001E886973AE0>
# <Element 'row' at 0x000001E886973BD0>
# <Element 'row' at 0x000001E886973D10>
# <Element 'row' at 0x000001E886973E00>
# <Element 'row' at 0x000001E886973F40>
# <Element 'row' at 0x000001E8869770E0>
# <Element 'row' at 0x000001E886977220>
# ...

# %%
data_df = pd.read_csv(r"D:\my_projects\stack_overflow_qwery_prediction_dvc_cicd\artifacts\prepared\train.tsv", encoding='utf-8', delimiter='\t', header=None, names=["Id", "Label", "Text"])

# %%
data_df
# Out:
#              Id  Label                                               Text
# 0       4186249      1  Searching and capturing a character using regu...
# 1         54312      0   <p>Yes, of course there is :-) object oriente...
# 2       7956164      0   <p>Try waiting for window's <code>load</code>...
# 3      39424767      0  android studio emulator: WARNING: Increasing R...
# 4      10314039      0   <p>Usually when the add-to-cart button does n...
# ...         ...    ...                                                ...
# 17355  20632342      0   <p>Just change your for loop,</p>  <pre><code...
# 17356  21748244      0   <p>You might also consider using <a href="htt...
# 17357  34690192      0   <p>try as follows</p>  <pre><code>  /*** mysq...
# 17358  26905220      0   <p>Create a <code>List&lt;TextBox&gt;</code> ...
# 17359   1518781      0   <p>You can use <a href="http://msdn.microsoft...
#
# [17360 rows x 3 columns]

# %%
data_df["Text"].str.lower().astype("U")[87]
# Out:
# 'count number of foreign keys in django <p>i\'ve read the documentation and all the other answers on here but i can\'t seem to get my head around it. </p>  <p><strong>i need to count the number of foreign keys in an other table connected by a foreign key to a row from a queryset.</strong></p>  <pre><code>class partreference(models.model):     name = models.charfield(max_length=10)     code = models.integerfield()  class part(models.model):     code = models.foreignkey(partreference)     serial_number = models.integerfield() </code></pre>  <p>i\'ll do something like:</p>  <pre><code>results = partreference.objects.all() </code></pre>  <p>but i want a variable containing the count of the number of parts like any other field, something like:</p>  <pre><code>results[0].count </code></pre>  <p>to ultimately do something like:</p>  <pre><code>print(results[0].name, results[0].code, results[0].count) </code></pre>  <p>i can\'t wrap my head around the <a href="https://docs.djangoproject.com/
# ...

# %%
data_df[data_df["Label"] == 1]
# Out:
#              Id  Label                                               Text
# 0       4186249      1  Searching and capturing a character using regu...
# 56     25184607      1  Sort a dictionary of arrays in python with a t...
# 87     34508804      1  Count number of foreign keys in Django <p>I've...
# 102      207981      1  How to enable MySQL client auto re-connect wit...
# 184    37551807      1  How to send multiple messages to eventhub usin...
# ...         ...    ...                                                ...
# 17139  35974432      1  Django NoReverseMatch at / <p>I am trying to a...
# 17219  27159324      1  How to find Python Module Size <p>Googling did...
# 17244  10664254      1  The right way to check of a string has hebrew ...
# 17258  22899890      1  Get Power (Voltage/Watts) with python or bash ...
# 17285  10728042      1  Break multiple lines in a text file into a lis...
#
# [348 rows x 3 columns]
